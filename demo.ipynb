# %% [markdown]
# #Image captioning results visualization
#
# ### A. Fine-tuning pre-trained VitGpt2 model on similar image captioning dataset (Flickr)
# - Purpose: To sanity-check image captioning fine-tuning architecture on an easy task
# - Pre-trained VitGpt2 model: https://huggingface.co/nlpconnect/vit-gpt2-image-captioning
# - Flickr dataset: https://www.kaggle.com/datasets/adityajn105/flickr30k
#
#
# ####*Training details*:
# - Unfroze last layer of Vit encoder and GPT2 decoder
# - Trained for 2 epochs
# - NOTE: number of unfrozen layers and number of epochs was minimized to compensate for limited personal resources.
#     - Therefore, these results should be taken as proof of concept, rather than optimal results

# %%
# Set up
from google.colab import drive
drive.mount('/content/drive')

import os
os.chdir("/content/drive/MyDrive/Code/Medical_Image_Captioning/")
os.chdir("/content/drive/MyDrive/Code/Medical_Image_Captioning/src")

import sys
sys.path.append('/content/drive/MyDrive/Code/Medical_Image_Captioning/')

# !pip install torch
# !pip install torchvision
# !pip install transformers
# !pip install hydra-core
# !pip install pytorch-lightning
# !pip install torchmetrics
# !pip install pillow
# !pip install transformers
# !pip install python-dotenv
# !pip install rich
# !pip install hydra-colorlog
# !pip install nltk
# !pip install rouge
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !python evaluate.py ckpt_path="/content/drive/MyDrive/Code/Medical_Image_Captioning/src/demo/flickr/2022-12-28_15-37-35/checkpoints/epoch_000.ckpt"
# Out:
# [2022-12-28 17:08:03,603][utils.utils][INFO] - Enforcing tags! <cfg.extras.enforce_tags=True>
# [2022-12-28 17:08:03,613][utils.utils][INFO] - Printing config tree with Rich! <cfg.extras.print_config=True>
# CONFIG
# ├── datamodule
# │   └── _target_: src.datamodule.flickr.FlickrDatamodule
# │       data_dir: data/flickr/
# │       train_ratio: 0.8
# │       val_ratio: 0.1
# │       test_ratio: 0.1
# │       batch_size: 64
# │       num_workers: 0
# │       pin_memory: false
# │
# ├── model
# │   └── _target_: src.models.vit_gpt2.VitGpt2
# │       optimizer:
# │         _target_: torch.optim.Adam
# │         _partial_: true
# │         lr: 0.001
# │         weight_decay: 0.0
# │       scheduler:
# │         _target_: torch.optim.lr_scheduler.ReduceLROnPlateau
# │         _partial_: true
# │         mode: min
# │         factor: 0.1
# │         patience: 10
# │       data_dir: null
# │       max_length: 16
# │       num_beams: 4
# │
# ├── callbacks
# │   └── model_checkpoint:
# ...

# %%
# Load trained model 
datamodule, model = load_run_components()


# Load datamodule (NOTE: using same random state should return same datamodule. did not save to save during training to save on space)
# View tensorboard logs


# Run sample inference on images from the test set

# %% [markdown]
# ### B. Fine-tuning pre-trained VitGPT2 model on medical image captioning dataset (MediCat)
