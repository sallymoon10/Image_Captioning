# %%
# View colab pro settings
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)

from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Wed Dec 28 21:26:18 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   49C    P0    27W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# Set up
from google.colab import drive
drive.mount('/content/drive')

import os
os.chdir("/content/drive/MyDrive/Code/Medical_Image_Captioning/")
os.chdir("/content/drive/MyDrive/Code/Medical_Image_Captioning/src")

# Poetry has issues running on colab. need to install packages with pip
# !pip install torch
# !pip install torchvision
# !pip install transformers
# !pip install hydra-core
# !pip install pytorch-lightning
# !pip install torchmetrics
# !pip install pillow
# !pip install transformers
# !pip install python-dotenv
# !pip install rich
# !pip install hydra-colorlog
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# Unzip data folders
# import shutil 
# shutil.unpack_archive("drive/MyDrive/Code/Medical_Image_Captioning/src/data/flickr/archive.zip", "drive/MyDrive/Code/Medical_Image_Captioning/src/data/flickr/")

# %%
# !python train.py datamodule.num_samples=10000
# Out:
# Streaming output truncated to the last 5000 lines.
# HPU available: False, using: 0 HPUs
# [2022-12-28 21:27:52,432][__main__][INFO] - Logging hyperparameters!
# [2022-12-28 21:27:52,456][__main__][INFO] - Starting training!
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# ┏━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━┳━━━━┓
# ┃   ┃ Name                                                            ┃ … ┃ P… ┃
# ┡━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━╇━━━━┩
# │ 0 │ model                                                           │ … │ 2… │
# │   │                                                                 │   │  M │
# │ 1 │ model.encoder                                                   │ … │ 8… │
# │   │                                                                 │   │  M │
# │ 2 │ model.encoder.embeddings                                        │ … │ 7… │
# ...
